# %% [markdown]
# # [ ML ]  대출연체 여부 예측

# %%
import pandas as pd 
import numpy as np

import seaborn as sns
import matplotlib.pyplot as plt

from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier

import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ### (0) 문제정의하기
# - 전처리 작업을 마친 데이터셋을 이용하여 대출 연체 여부를 예측해보세요

# %% [markdown]
# ### (1) 데이터 불러오기

# %%
df = pd.read_csv('loan_data_preprocessed.csv')

# %% [markdown]
# ### (2) 데이터 확인하기

# %%
df.head()
# Out:
#        Loan_ID         loan_status  Principal  terms effective_date  \
# 0  xqd20160234             PAIDOFF       1000     30     2016-09-12
# 1  xqd20160329          COLLECTION       1000     30     2016-09-11
# 2  xqd20160179             PAIDOFF       1000     30     2016-09-12
# 3  xqd20160454  COLLECTION_PAIDOFF       1000     30     2016-09-12
# 4  xqd20320403  COLLECTION_PAIDOFF       1000     30     2016-09-09
#
#      due_date  past_due_days  age  Gender  loan_duration  check_duration  \
# 0  2016-10-11            0.0   36    male             30            True
# 1  2016-10-10           59.0   24  female             30            True
# 2  2016-10-11            0.0   21    male             30            True
# 3  2016-10-11            3.0   26    male             30            True
# 4  2016-11-07           13.0   39    male             60           False
#
#    effective_month  effective_day  effective_weekday  Principal_log  \
# 0                9             12                  0       6.908755
# 1                9             11                  6       6.908755
# 2                9             12                  0       6.908755
# 3                9             12                  0       6.908755
# 4                9              9                  4       6.908755
#
#    education_High School or Below  education_Master or Above  \
# 0                            True                      False
# 1                            True                      False
# 2                            True                      False
# 3                            True                      False
# 4                           False                      False
#
#    education_college             education  Gender_label
# 0              False  High School or Below             0
# 1              False  High School or Below             1
# 2              False  High School or Below             0
# 3              False  High School or Below             0
# 4               True               college             0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 379 entries, 0 to 378
# Data columns (total 20 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Loan_ID                         379 non-null    object
#  1   loan_status                     379 non-null    object
#  2   Principal                       379 non-null    int64
#  3   terms                           379 non-null    int64
#  4   effective_date                  379 non-null    object
#  5   due_date                        379 non-null    object
#  6   past_due_days                   379 non-null    float64
#  7   age                             379 non-null    int64
#  8   Gender                          379 non-null    object
#  9   loan_duration                   379 non-null    int64
#  10  check_duration                  379 non-null    bool
#  11  effective_month                 379 non-null    int64
#  12  effective_day                   379 non-null    int64
#  13  effective_weekday               379 non-null    int64
#  14  Principal_log                   379 non-null    float64
#  15  education_High School or Below  379 non-null    bool
#  16  education_Master or Above       379 non-null    bool
#  17  education_college               379 non-null    bool
#  18  education                       379 non-null    object
#  19  Gender_label                    379 non-null    int64
# dtypes: bool(4), float64(2), int64(8), object(6)
# memory usage: 49.0+ KB

# %%
# numeric 형
df.describe()
# Out:
#          Principal       terms  past_due_days         age  loan_duration  \
# count   379.000000  379.000000     379.000000  379.000000     379.000000
# mean    999.472296   25.274406      14.147757   30.643799      27.862797
# std       7.254712    7.383928      24.467110    5.795664      10.907604
# min     900.000000    7.000000       0.000000   18.000000       7.000000
# 25%    1000.000000   15.000000       0.000000   26.000000      15.000000
# 50%    1000.000000   30.000000       0.000000   30.000000      30.000000
# 75%    1000.000000   30.000000      14.000000   34.000000      30.000000
# max    1000.000000   30.000000      76.000000   50.000000      60.000000
#
#        effective_month  effective_day  effective_weekday  Principal_log  \
# count            379.0     379.000000         379.000000     379.000000
# mean               9.0      11.390501           3.564644       6.908199
# std                0.0       1.093760           2.683068       0.007636
# min                9.0       8.000000           0.000000       6.803505
# 25%                9.0      11.000000           0.000000       6.908755
# 50%                9.0      11.000000           5.000000       6.908755
# 75%                9.0      12.000000           6.000000       6.908755
# max                9.0      14.000000           6.000000       6.908755
#
#        Gender_label
# count    379.000000
# mean       0.153034
# std        0.360496
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%        0.000000
# max        1.000000

# %%
# object 형
df.describe(include='object')
# Out:
#             Loan_ID loan_status effective_date    due_date Gender  \
# count           379         379            379         379    379
# unique          379           3              7          24      2
# top     xqd20160490     PAIDOFF     2016-09-11  2016-10-10   male
# freq              1         222            176         121    321
#
#                    education
# count                    379
# unique                     4
# top     High School or Below
# freq                     165

# %%
# 모든 열
df.describe(include='all')
# Out:
#             Loan_ID loan_status    Principal       terms effective_date  \
# count           379         379   379.000000  379.000000            379
# unique          379           3          NaN         NaN              7
# top     xqd20160490     PAIDOFF          NaN         NaN     2016-09-11
# freq              1         222          NaN         NaN            176
# mean            NaN         NaN   999.472296   25.274406            NaN
# std             NaN         NaN     7.254712    7.383928            NaN
# min             NaN         NaN   900.000000    7.000000            NaN
# 25%             NaN         NaN  1000.000000   15.000000            NaN
# 50%             NaN         NaN  1000.000000   30.000000            NaN
# 75%             NaN         NaN  1000.000000   30.000000            NaN
# max             NaN         NaN  1000.000000   30.000000            NaN
#
#           due_date  past_due_days         age Gender  loan_duration  \
# count          379     379.000000  379.000000    379     379.000000
# unique          24            NaN         NaN      2            NaN
# top     2016-10-10            NaN         NaN   male            NaN
# freq           121            NaN         NaN    321            NaN
# mean           NaN      14.147757   30.643799    NaN      27.862797
# std            NaN      24.467110    5.795664    NaN      10.907604
# min            NaN       0.000000   18.000000    NaN       7.000000
# 25%            NaN       0.000000   26.000000    NaN      15.000000
# 50%            NaN       0.000000   30.000000    NaN      30.000000
# 75%            NaN      14.000000   34.000000    NaN      30.000000
# max            NaN      76.000000   50.000000    NaN      60.000000
#
#        check_duration  effective_month  effective_day  effective_weekday  \
# count             379            379.0     379.000000         379.000000
# unique              2              NaN            NaN                NaN
# top              True              NaN            NaN                NaN
# freq              341              NaN            NaN                NaN
# mean              NaN              9.0      11.390501           3.564644
# std               NaN              0.0       1.093760           2.683068
# min               NaN              9.0       8.000000           0.000000
# 25%               NaN              9.0      11.000000           0.000000
# 50%               NaN              9.0      11.000000           5.000000
# 75%               NaN              9.0      12.000000           6.000000
# max               NaN              9.0      14.000000           6.000000
#
#         Principal_log education_High School or Below  \
# count      379.000000                            379
# unique            NaN                              2
# top               NaN                          False
# freq              NaN                            214
# mean         6.908199                            NaN
# std          0.007636                            NaN
# min          6.803505                            NaN
# 25%          6.908755                            NaN
# 50%          6.908755                            NaN
# 75%          6.908755                            NaN
# max          6.908755                            NaN
#
#        education_Master or Above education_college             education  \
# count                        379               379                   379
# unique                         2                 2                     4
# top                        False             False  High School or Below
# freq                         378               216                   165
# mean                         NaN               NaN                   NaN
# std                          NaN               NaN                   NaN
# min                          NaN               NaN                   NaN
# 25%                          NaN               NaN                   NaN
# 50%                          NaN               NaN                   NaN
# 75%                          NaN               NaN                   NaN
# max                          NaN               NaN                   NaN
#
#         Gender_label
# count     379.000000
# unique           NaN
# top              NaN
# freq             NaN
# mean        0.153034
# std         0.360496
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         0.000000
# max         1.000000

# %% [markdown]
# ### (3) 데이터 탐색하기

# %%
# loan_status 열
df['loan_status'].value_counts()
# Out:
# loan_status
# PAIDOFF               222
# COLLECTION_PAIDOFF     80
# COLLECTION             77
# Name: count, dtype: int64

# %%
# 정상 대출과 연체 대출을 0과 1로 변환
df['loan_status'] = df['loan_status'].map({'PAIDOFF':0, 'COLLECTION_PAIDOFF':1, 'COLLECTION':1}) 

df['loan_status'].value_counts()
# Out:
# loan_status
# 0    222
# 1    157
# Name: count, dtype: int64

# %%
# 성별에 따른 대출 상태
df.groupby(['Gender'])['loan_status'].mean()
# Out:
# Gender
# female    0.310345
# male      0.433022
# Name: loan_status, dtype: float64

# %%
# 교육 수준에 따른 대출 상태
df.groupby(['education'])['loan_status'].mean()
# Out:
# education
# Bechalor                0.360000
# High School or Below    0.430303
# Master or Above         1.000000
# college                 0.411043
# Name: loan_status, dtype: float64

# %%
# 성별에 따른 대출 연체일수 평균
df.groupby(['Gender'])['past_due_days'].mean()
# Out:
# Gender
# female     9.965517
# male      14.903427
# Name: past_due_days, dtype: float64

# %%
# 교육 수준에 따른 대출 연체일수 평균
df.groupby(['education'])['past_due_days'].mean()
# Out:
# education
# Bechalor                11.400000
# High School or Below    15.739394
# Master or Above         74.000000
# college                 13.012270
# Name: past_due_days, dtype: float64

# %% [markdown]
# ### (4) 학습용 데이터셋 만들기

# %%
df.head(1)
# Out:
#        Loan_ID  loan_status  Principal  terms effective_date    due_date  \
# 0  xqd20160234            0       1000     30     2016-09-12  2016-10-11
#
#    past_due_days  age Gender  loan_duration  check_duration  effective_month  \
# 0            0.0   36   male             30            True                9
#
#    effective_day  effective_weekday  Principal_log  \
# 0             12                  0       6.908755
#
#    education_High School or Below  education_Master or Above  \
# 0                            True                      False
#
#    education_college             education  Gender_label
# 0              False  High School or Below             0

# %%
# feature data 와 target data 분리
X = df[['Principal', 'terms', 'age', 'loan_duration',
       'education_High School or Below', 'education_Master or Above',
       'education_college', 'Gender_label']]

y = df['loan_status']

X.shape, y.shape
# Out:
# ((379, 8), (379,))

# %%
# feature data
X.head(1)
# Out:
#    Principal  terms  age  loan_duration  education_High School or Below  \
# 0       1000     30   36             30                            True
#
#    education_Master or Above  education_college  Gender_label
# 0                      False              False             0

# %%
# target data 결측치 확인
X.isnull().sum()
# Out:
# Principal                         0
# terms                             0
# age                               0
# loan_duration                     0
# education_High School or Below    0
# education_Master or Above         0
# education_college                 0
# Gender_label                      0
# dtype: int64

# %%
# target data 구성비율 확인
y.value_counts(normalize=True)
# Out:
# loan_status
# 0    0.585752
# 1    0.414248
# Name: proportion, dtype: float64

# %% [markdown]
# ### (5) 모델링 & 예측

# %%
# train, test 데이터 분리  
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((303, 8), (76, 8), (303,), (76,))

# %%
# Logistic Regression

logreg = LogisticRegression()
logreg.fit(X_train, y_train)
y_pred = logreg.predict(X_test)

acc_log = logreg.score(X_test, y_test)
print(acc_log)
# Out:
# 0.5921052631578947

# %%
# Support Vector Machines

svc = SVC()
svc.fit(X_train, y_train)
y_pred = svc.predict(X_test)

acc_svc = svc.score(X_test, y_test)
print(acc_svc)
# Out:
# 0.5921052631578947

# %%
# Random Forest

random_forest = RandomForestClassifier(n_estimators=100)
random_forest.fit(X_train, y_train)
y_pred = random_forest.predict(X_test)

acc_random_forest = random_forest.score(X_test, y_test)
print(acc_random_forest)
# Out:
# 0.5

# %% [markdown]
# ### (6) 모델 예측 결과 정리

# %%
models = pd.DataFrame({
    'Model': ['Support Vector Machines', 'Logistic Regression', 'Random Forest',],
    'Score': [acc_svc,acc_log, acc_random_forest, ]})
    
models.sort_values(by='Score', ascending=False)
# Out:
#                      Model     Score
# 0  Support Vector Machines  0.592105
# 1      Logistic Regression  0.592105
# 2            Random Forest  0.500000
